# %%
import pandas as pd

# %%
df = pd.read_csv('./titanic_data.csv')

# %%
df.head(10)
# Out:
#   Passenger Class                                             Name     Sex  \
# 0           First                    Allen, Miss. Elisabeth Walton  Female
# 1           First                   Allison, Master. Hudson Trevor    Male
# 2           First                     Allison, Miss. Helen Loraine  Female
# 3           First             Allison, Mr. Hudson Joshua Creighton    Male
# 4           First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# 5           First                              Anderson, Mr. Harry    Male
# 6           First                Andrews, Miss. Kornelia Theodosia  Female
# 7           First                           Andrews, Mr. Thomas Jr    Male
# 8           First    Appleton, Mrs. Edward Dale (Charlotte Lamson)  Female
# 9           First                          Artagaveytia, Mr. Ramon    Male
#
#        Age  No of Siblings or Spouses on Board  \
# 0  29.0000                                   0
# 1   0.9167                                   1
# 2   2.0000                                   1
# 3  30.0000                                   1
# 4  25.0000                                   1
# 5  48.0000                                   0
# 6  63.0000                                   1
# 7  39.0000                                   0
# 8  53.0000                                   2
# 9  71.0000                                   0
#
#    No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 0                                   0         24160        211.3375       B5
# 1                                   2        113781        151.5500  C22 C26
# 2                                   2        113781        151.5500  C22 C26
# 3                                   2        113781        151.5500  C22 C26
# 4                                   2        113781        151.5500  C22 C26
# 5                                   0         19952         26.5500      E12
# 6                                   0         13502         77.9583       D7
# 7                                   0        112050          0.0000      A36
# 8                                   0         11769         51.4792     C101
# 9                                   0      PC 17609         49.5042      NaN
#
#   Port of Embarkation Life Boat Survived
# 0         Southampton         2      Yes
# 1         Southampton        11      Yes
# 2         Southampton       NaN       No
# 3         Southampton       NaN       No
# 4         Southampton       NaN       No
# 5         Southampton         3      Yes
# 6         Southampton        10      Yes
# 7         Southampton       NaN       No
# 8         Southampton         D      Yes
# 9           Cherbourg       NaN       No

# %%
df.iloc[10:20]
# Out:
#    Passenger Class                                               Name     Sex  \
# 10           First                             Astor, Col. John Jacob    Male
# 11           First  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  Female
# 12           First                      Aubart, Mme. Leontine Pauline  Female
# 13           First                       Barber, Miss. Ellen 'Nellie'  Female
# 14           First               Barkworth, Mr. Algernon Henry Wilson    Male
# 15           First                                Baumann, Mr. John D    Male
# 16           First                           Baxter, Mr. Quigg Edmond    Male
# 17           First    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  Female
# 18           First                              Bazzani, Miss. Albina  Female
# 19           First                               Beattie, Mr. Thomson    Male
#
#      Age  No of Siblings or Spouses on Board  \
# 10  47.0                                   1
# 11  18.0                                   1
# 12  24.0                                   0
# 13  26.0                                   0
# 14  80.0                                   0
# 15   NaN                                   0
# 16  24.0                                   0
# 17  50.0                                   0
# 18  32.0                                   0
# 19  36.0                                   0
#
#     No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 10                                   0      PC 17757        227.5250  C62 C64
# 11                                   0      PC 17757        227.5250  C62 C64
# 12                                   0      PC 17477         69.3000      B35
# 13                                   0         19877         78.8500      NaN
# 14                                   0         27042         30.0000      A23
# 15                                   0      PC 17318         25.9250      NaN
# 16                                   1      PC 17558        247.5208  B58 B60
# 17                                   1      PC 17558        247.5208  B58 B60
# 18                                   0         11813         76.2917      D15
# 19                                   0         13050         75.2417       C6
#
#    Port of Embarkation Life Boat Survived
# 10           Cherbourg       NaN       No
# 11           Cherbourg         4      Yes
# 12           Cherbourg         9      Yes
# 13         Southampton         6      Yes
# 14         Southampton         B      Yes
# 15         Southampton       NaN       No
# 16           Cherbourg       NaN       No
# 17           Cherbourg         6      Yes
# 18           Cherbourg         8      Yes
# 19           Cherbourg         A       No

# %%
df.loc[10:20]
# Out:
#    Passenger Class                                               Name     Sex  \
# 10           First                             Astor, Col. John Jacob    Male
# 11           First  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  Female
# 12           First                      Aubart, Mme. Leontine Pauline  Female
# 13           First                       Barber, Miss. Ellen 'Nellie'  Female
# 14           First               Barkworth, Mr. Algernon Henry Wilson    Male
# 15           First                                Baumann, Mr. John D    Male
# 16           First                           Baxter, Mr. Quigg Edmond    Male
# 17           First    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  Female
# 18           First                              Bazzani, Miss. Albina  Female
# 19           First                               Beattie, Mr. Thomson    Male
# 20           First                      Beckwith, Mr. Richard Leonard    Male
#
#      Age  No of Siblings or Spouses on Board  \
# 10  47.0                                   1
# 11  18.0                                   1
# 12  24.0                                   0
# 13  26.0                                   0
# 14  80.0                                   0
# 15   NaN                                   0
# 16  24.0                                   0
# 17  50.0                                   0
# 18  32.0                                   0
# 19  36.0                                   0
# 20  37.0                                   1
#
#     No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 10                                   0      PC 17757        227.5250  C62 C64
# 11                                   0      PC 17757        227.5250  C62 C64
# 12                                   0      PC 17477         69.3000      B35
# 13                                   0         19877         78.8500      NaN
# 14                                   0         27042         30.0000      A23
# 15                                   0      PC 17318         25.9250      NaN
# 16                                   1      PC 17558        247.5208  B58 B60
# 17                                   1      PC 17558        247.5208  B58 B60
# 18                                   0         11813         76.2917      D15
# 19                                   0         13050         75.2417       C6
# 20                                   1         11751         52.5542      D35
#
#    Port of Embarkation Life Boat Survived
# 10           Cherbourg       NaN       No
# 11           Cherbourg         4      Yes
# 12           Cherbourg         9      Yes
# 13         Southampton         6      Yes
# 14         Southampton         B      Yes
# 15         Southampton       NaN       No
# 16           Cherbourg       NaN       No
# 17           Cherbourg         6      Yes
# 18           Cherbourg         8      Yes
# 19           Cherbourg         A       No
# 20         Southampton         5      Yes

# %%
df.columns
# Out:
# Index(['Passenger Class', 'Name', 'Sex', 'Age',
#        'No of Siblings or Spouses on Board',
#        'No of Parents or Children on Board', 'Ticket Number', 'Passenger Fare',
#        'Cabin', 'Port of Embarkation', 'Life Boat', 'Survived'],
#       dtype='object')

# %%
df.shape
# Out:
# (1309, 12)

# %%
df.count()
# Out:
# Passenger Class                       1309
# Name                                  1309
# Sex                                   1309
# Age                                   1046
# No of Siblings or Spouses on Board    1309
# No of Parents or Children on Board    1309
# Ticket Number                         1309
# Passenger Fare                        1308
# Cabin                                  295
# Port of Embarkation                   1307
# Life Boat                              486
# Survived                              1309
# dtype: int64

# %%
df.tail(10)
# Out:
#      Passenger Class                                     Name     Sex   Age  \
# 1299           Third                      Yasbeck, Mr. Antoni    Male  27.0
# 1300           Third  Yasbeck, Mrs. Antoni (Selini Alexander)  Female  15.0
# 1301           Third                     Youseff, Mr. Gerious    Male  45.5
# 1302           Third                        Yousif, Mr. Wazli    Male   NaN
# 1303           Third                    Yousseff, Mr. Gerious    Male   NaN
# 1304           Third                     Zabour, Miss. Hileni  Female  14.5
# 1305           Third                    Zabour, Miss. Thamine  Female   NaN
# 1306           Third                Zakarian, Mr. Mapriededer    Male  26.5
# 1307           Third                      Zakarian, Mr. Ortin    Male  27.0
# 1308           Third                       Zimmerman, Mr. Leo    Male  29.0
#
#       No of Siblings or Spouses on Board  No of Parents or Children on Board  \
# 1299                                   1                                   0
# 1300                                   1                                   0
# 1301                                   0                                   0
# 1302                                   0                                   0
# 1303                                   0                                   0
# 1304                                   1                                   0
# 1305                                   1                                   0
# 1306                                   0                                   0
# 1307                                   0                                   0
# 1308                                   0                                   0
#
#      Ticket Number  Passenger Fare Cabin Port of Embarkation Life Boat  \
# 1299          2659         14.4542   NaN           Cherbourg         C
# 1300          2659         14.4542   NaN           Cherbourg       NaN
# 1301          2628          7.2250   NaN           Cherbourg       NaN
# 1302          2647          7.2250   NaN           Cherbourg       NaN
# 1303          2627         14.4583   NaN           Cherbourg       NaN
# 1304          2665         14.4542   NaN           Cherbourg       NaN
# 1305          2665         14.4542   NaN           Cherbourg       NaN
# 1306          2656          7.2250   NaN           Cherbourg       NaN
# 1307          2670          7.2250   NaN           Cherbourg       NaN
# 1308        315082          7.8750   NaN         Southampton       NaN
#
#      Survived
# 1299       No
# 1300      Yes
# 1301       No
# 1302       No
# 1303       No
# 1304       No
# 1305       No
# 1306       No
# 1307       No
# 1308       No

# %%
df.Sex
# Out:
# 0       Female
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 1304    Female
# 1305    Female
# 1306      Male
# 1307      Male
# 1308      Male
# Name: Sex, Length: 1309, dtype: object

# %%
df['Sex']
# Out:
# 0       Female
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 1304    Female
# 1305    Female
# 1306      Male
# 1307      Male
# 1308      Male
# Name: Sex, Length: 1309, dtype: object

# %%
df['Passenger Class']
# Out:
# 0       First
# 1       First
# 2       First
# 3       First
# 4       First
#         ...
# 1304    Third
# 1305    Third
# 1306    Third
# 1307    Third
# 1308    Third
# Name: Passenger Class, Length: 1309, dtype: object

# %%
df.iloc[4:14]
# Out:
#    Passenger Class                                               Name     Sex  \
# 4            First    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# 5            First                                Anderson, Mr. Harry    Male
# 6            First                  Andrews, Miss. Kornelia Theodosia  Female
# 7            First                             Andrews, Mr. Thomas Jr    Male
# 8            First      Appleton, Mrs. Edward Dale (Charlotte Lamson)  Female
# 9            First                            Artagaveytia, Mr. Ramon    Male
# 10           First                             Astor, Col. John Jacob    Male
# 11           First  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  Female
# 12           First                      Aubart, Mme. Leontine Pauline  Female
# 13           First                       Barber, Miss. Ellen 'Nellie'  Female
#
#      Age  No of Siblings or Spouses on Board  \
# 4   25.0                                   1
# 5   48.0                                   0
# 6   63.0                                   1
# 7   39.0                                   0
# 8   53.0                                   2
# 9   71.0                                   0
# 10  47.0                                   1
# 11  18.0                                   1
# 12  24.0                                   0
# 13  26.0                                   0
#
#     No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 4                                    2        113781        151.5500  C22 C26
# 5                                    0         19952         26.5500      E12
# 6                                    0         13502         77.9583       D7
# 7                                    0        112050          0.0000      A36
# 8                                    0         11769         51.4792     C101
# 9                                    0      PC 17609         49.5042      NaN
# 10                                   0      PC 17757        227.5250  C62 C64
# 11                                   0      PC 17757        227.5250  C62 C64
# 12                                   0      PC 17477         69.3000      B35
# 13                                   0         19877         78.8500      NaN
#
#    Port of Embarkation Life Boat Survived
# 4          Southampton       NaN       No
# 5          Southampton         3      Yes
# 6          Southampton        10      Yes
# 7          Southampton       NaN       No
# 8          Southampton         D      Yes
# 9            Cherbourg       NaN       No
# 10           Cherbourg       NaN       No
# 11           Cherbourg         4      Yes
# 12           Cherbourg         9      Yes
# 13         Southampton         6      Yes

# %%
df.loc[4:14]
# Out:
#    Passenger Class                                               Name     Sex  \
# 4            First    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# 5            First                                Anderson, Mr. Harry    Male
# 6            First                  Andrews, Miss. Kornelia Theodosia  Female
# 7            First                             Andrews, Mr. Thomas Jr    Male
# 8            First      Appleton, Mrs. Edward Dale (Charlotte Lamson)  Female
# 9            First                            Artagaveytia, Mr. Ramon    Male
# 10           First                             Astor, Col. John Jacob    Male
# 11           First  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  Female
# 12           First                      Aubart, Mme. Leontine Pauline  Female
# 13           First                       Barber, Miss. Ellen 'Nellie'  Female
# 14           First               Barkworth, Mr. Algernon Henry Wilson    Male
#
#      Age  No of Siblings or Spouses on Board  \
# 4   25.0                                   1
# 5   48.0                                   0
# 6   63.0                                   1
# 7   39.0                                   0
# 8   53.0                                   2
# 9   71.0                                   0
# 10  47.0                                   1
# 11  18.0                                   1
# 12  24.0                                   0
# 13  26.0                                   0
# 14  80.0                                   0
#
#     No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 4                                    2        113781        151.5500  C22 C26
# 5                                    0         19952         26.5500      E12
# 6                                    0         13502         77.9583       D7
# 7                                    0        112050          0.0000      A36
# 8                                    0         11769         51.4792     C101
# 9                                    0      PC 17609         49.5042      NaN
# 10                                   0      PC 17757        227.5250  C62 C64
# 11                                   0      PC 17757        227.5250  C62 C64
# 12                                   0      PC 17477         69.3000      B35
# 13                                   0         19877         78.8500      NaN
# 14                                   0         27042         30.0000      A23
#
#    Port of Embarkation Life Boat Survived
# 4          Southampton       NaN       No
# 5          Southampton         3      Yes
# 6          Southampton        10      Yes
# 7          Southampton       NaN       No
# 8          Southampton         D      Yes
# 9            Cherbourg       NaN       No
# 10           Cherbourg       NaN       No
# 11           Cherbourg         4      Yes
# 12           Cherbourg         9      Yes
# 13         Southampton         6      Yes
# 14         Southampton         B      Yes

# %% [markdown]
# # Build a daseline model

# %%
df.head(10)
# Out:
#   Passenger Class                                             Name     Sex  \
# 0           First                    Allen, Miss. Elisabeth Walton  Female
# 1           First                   Allison, Master. Hudson Trevor    Male
# 2           First                     Allison, Miss. Helen Loraine  Female
# 3           First             Allison, Mr. Hudson Joshua Creighton    Male
# 4           First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# 5           First                              Anderson, Mr. Harry    Male
# 6           First                Andrews, Miss. Kornelia Theodosia  Female
# 7           First                           Andrews, Mr. Thomas Jr    Male
# 8           First    Appleton, Mrs. Edward Dale (Charlotte Lamson)  Female
# 9           First                          Artagaveytia, Mr. Ramon    Male
#
#        Age  No of Siblings or Spouses on Board  \
# 0  29.0000                                   0
# 1   0.9167                                   1
# 2   2.0000                                   1
# 3  30.0000                                   1
# 4  25.0000                                   1
# 5  48.0000                                   0
# 6  63.0000                                   1
# 7  39.0000                                   0
# 8  53.0000                                   2
# 9  71.0000                                   0
#
#    No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 0                                   0         24160        211.3375       B5
# 1                                   2        113781        151.5500  C22 C26
# 2                                   2        113781        151.5500  C22 C26
# 3                                   2        113781        151.5500  C22 C26
# 4                                   2        113781        151.5500  C22 C26
# 5                                   0         19952         26.5500      E12
# 6                                   0         13502         77.9583       D7
# 7                                   0        112050          0.0000      A36
# 8                                   0         11769         51.4792     C101
# 9                                   0      PC 17609         49.5042      NaN
#
#   Port of Embarkation Life Boat Survived
# 0         Southampton         2      Yes
# 1         Southampton        11      Yes
# 2         Southampton       NaN       No
# 3         Southampton       NaN       No
# 4         Southampton       NaN       No
# 5         Southampton         3      Yes
# 6         Southampton        10      Yes
# 7         Southampton       NaN       No
# 8         Southampton         D      Yes
# 9           Cherbourg       NaN       No

# %%
df.dtypes
# Out:
# Passenger Class                        object
# Name                                   object
# Sex                                    object
# Age                                   float64
# No of Siblings or Spouses on Board      int64
# No of Parents or Children on Board      int64
# Ticket Number                          object
# Passenger Fare                        float64
# Cabin                                  object
# Port of Embarkation                    object
# Life Boat                              object
# Survived                               object
# dtype: object

# %%
num_columns = ['Age', 'No of Siblings or Spouses on Board', 'No of Parents or Children on Board', 'Passenger Fare']

df1 = df[num_columns]

# %%
df['Survived']
# Out:
# 0       Yes
# 1       Yes
# 2        No
# 3        No
# 4        No
#        ...
# 1304     No
# 1305     No
# 1306     No
# 1307     No
# 1308     No
# Name: Survived, Length: 1309, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[num_columns], df.Survived, train_size = 0.66, random_state = 5)

# %%
x_train.head()
# Out:
#       Age  No of Siblings or Spouses on Board  \
# 615  20.0                                   0
# 287  61.0                                   0
# 720  24.0                                   0
# 222  28.5                                   0
# 244  36.0                                   0
#
#      No of Parents or Children on Board  Passenger Fare
# 615                                   0          7.9250
# 287                                   0         32.3208
# 720                                   0          7.2500
# 222                                   0         27.7208
# 244                                   0         40.1250

# %%
x_train.shape
# Out:
# (863, 4)

# %%
x_test.shape
# Out:
# (446, 4)

# %%
y_test.shape
# Out:
# (446,)

# %%
clf = DecisionTreeClassifier(max_depth = 5)

# %%
x_test.count()
# Out:
# Age                                   350
# No of Siblings or Spouses on Board    446
# No of Parents or Children on Board    446
# Passenger Fare                        445
# dtype: int64

# %%
mean_age = x_train['Age'].mean()

x_train['Age'] = x_train['Age'].fillna(value = mean_age)

mean_fare = x_train['Passenger Fare'].mean()

x_train['Passenger Fare'] = x_train['Passenger Fare'].fillna(value = mean_fare)

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
x_test['Age'] = x_test['Age'].fillna(value = mean_age)
x_test['Passenger Fare'] = x_test['Passenger Fare'].fillna(value = mean_fare)

# %%
y_pred = clf.predict(x_test)

# %%
sum(y_test == y_pred)
# Out:
# 298

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6681614349775785

# %%
y_test.value_counts()
# Out:
# Survived
# No     278
# Yes    168
# Name: count, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# Survived
# No     809
# Yes    500
# Name: count, dtype: int64

# %%
y_pred_const = ['No']*446

# %%
accuracy_score(y_test, y_pred_const)
# Out:
# 0.6233183856502242

# %% [markdown]
# # Exploratory data analysis (EDA)

# %%
import seaborn as sns

# %%
sns.countplot(data=df.Survived)
# Out:
# <Axes: xlabel='count', ylabel='Survived'>

# %%
df.head(10)
# Out:
#   Passenger Class                                             Name     Sex  \
# 0           First                    Allen, Miss. Elisabeth Walton  Female
# 1           First                   Allison, Master. Hudson Trevor    Male
# 2           First                     Allison, Miss. Helen Loraine  Female
# 3           First             Allison, Mr. Hudson Joshua Creighton    Male
# 4           First  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  Female
# 5           First                              Anderson, Mr. Harry    Male
# 6           First                Andrews, Miss. Kornelia Theodosia  Female
# 7           First                           Andrews, Mr. Thomas Jr    Male
# 8           First    Appleton, Mrs. Edward Dale (Charlotte Lamson)  Female
# 9           First                          Artagaveytia, Mr. Ramon    Male
#
#        Age  No of Siblings or Spouses on Board  \
# 0  29.0000                                   0
# 1   0.9167                                   1
# 2   2.0000                                   1
# 3  30.0000                                   1
# 4  25.0000                                   1
# 5  48.0000                                   0
# 6  63.0000                                   1
# 7  39.0000                                   0
# 8  53.0000                                   2
# 9  71.0000                                   0
#
#    No of Parents or Children on Board Ticket Number  Passenger Fare    Cabin  \
# 0                                   0         24160        211.3375       B5
# 1                                   2        113781        151.5500  C22 C26
# 2                                   2        113781        151.5500  C22 C26
# 3                                   2        113781        151.5500  C22 C26
# 4                                   2        113781        151.5500  C22 C26
# 5                                   0         19952         26.5500      E12
# 6                                   0         13502         77.9583       D7
# 7                                   0        112050          0.0000      A36
# 8                                   0         11769         51.4792     C101
# 9                                   0      PC 17609         49.5042      NaN
#
#   Port of Embarkation Life Boat Survived
# 0         Southampton         2      Yes
# 1         Southampton        11      Yes
# 2         Southampton       NaN       No
# 3         Southampton       NaN       No
# 4         Southampton       NaN       No
# 5         Southampton         3      Yes
# 6         Southampton        10      Yes
# 7         Southampton       NaN       No
# 8         Southampton         D      Yes
# 9           Cherbourg       NaN       No

# %%
df.Survived.value_counts()
# Out:
# Survived
# No     809
# Yes    500
# Name: count, dtype: int64

# %%
sns.countplot(data = df.Sex)
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
sns.catplot(x = 'Survived', col = 'Sex', kind = 'count', data = df);

# %%
sns.countplot(df, x = 'Survived');

# %% [markdown]
# # Passenger Class

# %%
sns.countplot(df, x = 'Passenger Class');

# %%
df.groupby('Passenger Class')['Passenger Fare'].mean()
# Out:
# Passenger Class
# First     87.508992
# Second    21.179196
# Third     13.302889
# Name: Passenger Fare, dtype: float64

# %%
sns.catplot(x = 'Survived', col = 'Passenger Class', kind = 'count', data = df);

# %% [markdown]
# ## Age

# %%
fig = sns.FacetGrid(df, hue = 'Survived', height = 5, aspect = 3)
fig.map(sns.kdeplot, 'Age', fill = True)
fig.add_legend();

# %%
df.groupby('Survived')['Age'].mean()
# Out:
# Survived
# No     30.545369
# Yes    28.918228
# Name: Age, dtype: float64

# %%
df.head(4)
# Out:
#   Passenger Class                                  Name     Sex      Age  \
# 0           First         Allen, Miss. Elisabeth Walton  Female  29.0000
# 1           First        Allison, Master. Hudson Trevor    Male   0.9167
# 2           First          Allison, Miss. Helen Loraine  Female   2.0000
# 3           First  Allison, Mr. Hudson Joshua Creighton    Male  30.0000
#
#    No of Siblings or Spouses on Board  No of Parents or Children on Board  \
# 0                                   0                                   0
# 1                                   1                                   2
# 2                                   1                                   2
# 3                                   1                                   2
#
#   Ticket Number  Passenger Fare    Cabin Port of Embarkation Life Boat  \
# 0         24160        211.3375       B5         Southampton         2
# 1        113781        151.5500  C22 C26         Southampton        11
# 2        113781        151.5500  C22 C26         Southampton       NaN
# 3        113781        151.5500  C22 C26         Southampton       NaN
#
#   Survived
# 0      Yes
# 1      Yes
# 2       No
# 3       No

# %%
fig = sns.FacetGrid(df, hue = 'Survived', height = 5, aspect = 3)
fig.map(sns.kdeplot, 'Passenger Fare', fill = True)
fig.add_legend();

# %%
sns.catplot(x = 'Survived', y = 'Passenger Fare', data = df, kind = 'box');

# %%
df[df['Passenger Fare'] > 200]
# Out:
#     Passenger Class                                               Name  \
# 0             First                      Allen, Miss. Elisabeth Walton
# 10            First                             Astor, Col. John Jacob
# 11            First  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 16            First                           Baxter, Mr. Quigg Edmond
# 17            First    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 23            First                              Bidois, Miss. Rosalie
# 24            First                                  Bird, Miss. Ellen
# 35            First                           Bowen, Miss. Grace Scott
# 49            First                 Cardeza, Mr. Thomas Drake Martinez
# 50            First  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 66            First                        Chaudanson, Miss. Victorine
# 97            First  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 103           First                      Endres, Miss. Caroline Louise
# 106           First                                 Farthing, Mr. John
# 111           First                     Fortune, Miss. Alice Elizabeth
# 112           First                         Fortune, Miss. Ethel Flora
# 113           First                         Fortune, Miss. Mabel Helen
# 114           First                     Fortune, Mr. Charles Alexander
# 115           First                                  Fortune, Mr. Mark
# 116           First                Fortune, Mrs. Mark (Mary McDougald)
# 129           First                               Geiger, Miss. Amalie
# 173           First                                 Keeping, Mr. Edwin
# 180           First                             Kreuchen, Miss. Emilie
# 183           First                             Lesurer, Mr. Gustave J
# 193           First                  Madill, Miss. Georgette Alexandra
# 237           First                                Robbins, Mr. Victor
# 238           First  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 249           First                        Ryerson, Master. John Borie
# 250           First                         Ryerson, Miss. Emily Borie
# 251           First              Ryerson, Miss. Susan Parker 'Suzette'
# 252           First                         Ryerson, Mr. Arthur Larned
# 253           First    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 285           First                                 Straus, Mr. Isidor
# 286           First             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 302           First                                   Ward, Miss. Anna
# 312           First                         Widener, Mr. George Dunton
# 313           First                          Widener, Mr. Harry Elkins
# 314           First       Widener, Mrs. George Dunton (Eleanor Elkins)
#
#         Sex   Age  No of Siblings or Spouses on Board  \
# 0    Female  29.0                                   0
# 10     Male  47.0                                   1
# 11   Female  18.0                                   1
# 16     Male  24.0                                   0
# 17   Female  50.0                                   0
# 23   Female  42.0                                   0
# 24   Female  29.0                                   0
# 35   Female  45.0                                   0
# 49     Male  36.0                                   0
# 50   Female  58.0                                   0
# 66   Female  36.0                                   0
# 97   Female  27.0                                   1
# 103  Female  38.0                                   0
# 106    Male   NaN                                   0
# 111  Female  24.0                                   3
# 112  Female  28.0                                   3
# 113  Female  23.0                                   3
# 114    Male  19.0                                   3
# 115    Male  64.0                                   1
# 116  Female  60.0                                   1
# 129  Female  35.0                                   0
# 173    Male  32.5                                   0
# 180  Female  39.0                                   0
# 183    Male  35.0                                   0
# 193  Female  15.0                                   0
# 237    Male   NaN                                   0
# 238  Female  43.0                                   0
# 249    Male  13.0                                   2
# 250  Female  18.0                                   2
# 251  Female  21.0                                   2
# 252    Male  61.0                                   1
# 253  Female  48.0                                   1
# 285    Male  67.0                                   1
# 286  Female  63.0                                   1
# 302  Female  35.0                                   0
# 312    Male  50.0                                   1
# 313    Male  27.0                                   0
# 314  Female  50.0                                   1
#
#      No of Parents or Children on Board Ticket Number  Passenger Fare  \
# 0                                     0         24160        211.3375
# 10                                    0      PC 17757        227.5250
# 11                                    0      PC 17757        227.5250
# 16                                    1      PC 17558        247.5208
# 17                                    1      PC 17558        247.5208
# 23                                    0      PC 17757        227.5250
# 24                                    0      PC 17483        221.7792
# 35                                    0      PC 17608        262.3750
# 49                                    1      PC 17755        512.3292
# 50                                    1      PC 17755        512.3292
# 66                                    0      PC 17608        262.3750
# 97                                    1      PC 17558        247.5208
# 103                                   0      PC 17757        227.5250
# 106                                   0      PC 17483        221.7792
# 111                                   2         19950        263.0000
# 112                                   2         19950        263.0000
# 113                                   2         19950        263.0000
# 114                                   2         19950        263.0000
# 115                                   4         19950        263.0000
# 116                                   4         19950        263.0000
# 129                                   0        113503        211.5000
# 173                                   0        113503        211.5000
# 180                                   0         24160        211.3375
# 183                                   0      PC 17755        512.3292
# 193                                   1         24160        211.3375
# 237                                   0      PC 17757        227.5250
# 238                                   1         24160        211.3375
# 249                                   2      PC 17608        262.3750
# 250                                   2      PC 17608        262.3750
# 251                                   2      PC 17608        262.3750
# 252                                   3      PC 17608        262.3750
# 253                                   3      PC 17608        262.3750
# 285                                   0      PC 17483        221.7792
# 286                                   0      PC 17483        221.7792
# 302                                   0      PC 17755        512.3292
# 312                                   1        113503        211.5000
# 313                                   2        113503        211.5000
# 314                                   1        113503        211.5000
#
#                Cabin Port of Embarkation Life Boat Survived
# 0                 B5         Southampton         2      Yes
# 10           C62 C64           Cherbourg       NaN       No
# 11           C62 C64           Cherbourg         4      Yes
# 16           B58 B60           Cherbourg       NaN       No
# 17           B58 B60           Cherbourg         6      Yes
# 23               NaN           Cherbourg         4      Yes
# 24               C97         Southampton         8      Yes
# 35               NaN           Cherbourg         4      Yes
# 49       B51 B53 B55           Cherbourg         3      Yes
# 50       B51 B53 B55           Cherbourg         3      Yes
# 66               B61           Cherbourg         4      Yes
# 97           B58 B60           Cherbourg         6      Yes
# 103              C45           Cherbourg         4      Yes
# 106              C95         Southampton       NaN       No
# 111      C23 C25 C27         Southampton        10      Yes
# 112      C23 C25 C27         Southampton        10      Yes
# 113      C23 C25 C27         Southampton        10      Yes
# 114      C23 C25 C27         Southampton       NaN       No
# 115      C23 C25 C27         Southampton       NaN       No
# 116      C23 C25 C27         Southampton        10      Yes
# 129             C130           Cherbourg         4      Yes
# 173             C132           Cherbourg       NaN       No
# 180              NaN         Southampton         2      Yes
# 183             B101           Cherbourg         3      Yes
# 193               B5         Southampton         2      Yes
# 237              NaN           Cherbourg       NaN       No
# 238               B3         Southampton         2      Yes
# 249  B57 B59 B63 B66           Cherbourg         4      Yes
# 250  B57 B59 B63 B66           Cherbourg         4      Yes
# 251  B57 B59 B63 B66           Cherbourg         4      Yes
# 252  B57 B59 B63 B66           Cherbourg       NaN       No
# 253  B57 B59 B63 B66           Cherbourg         4      Yes
# 285          C55 C57         Southampton       NaN       No
# 286          C55 C57         Southampton       NaN       No
# 302              NaN           Cherbourg         3      Yes
# 312              C80           Cherbourg       NaN       No
# 313              C82           Cherbourg       NaN       No
# 314              C80           Cherbourg         4      Yes

# %%
df.groupby('Survived')['Passenger Fare'].median()
# Out:
# Survived
# No     10.5
# Yes    26.0
# Name: Passenger Fare, dtype: float64

# %%
df.count()
# Out:
# Passenger Class                       1309
# Name                                  1309
# Sex                                   1309
# Age                                   1046
# No of Siblings or Spouses on Board    1309
# No of Parents or Children on Board    1309
# Ticket Number                         1309
# Passenger Fare                        1308
# Cabin                                  295
# Port of Embarkation                   1307
# Life Boat                              486
# Survived                              1309
# dtype: int64

# %%
df.dropna(subset = ['Life Boat']).Survived.value_counts()
# Out:
# Survived
# Yes    477
# No       9
# Name: count, dtype: int64

# %%
df[df['Life Boat'].isna()]['Survived'].value_counts()
# Out:
# Survived
# No     800
# Yes     23
# Name: count, dtype: int64

# %%
cat_columns = ['Passenger Class', 'Sex', 'Port of Embarkation']

dummy_columns = pd.get_dummies(df[cat_columns])

# %%
df[cat_columns].head(4)
# Out:
#   Passenger Class     Sex Port of Embarkation
# 0           First  Female         Southampton
# 1           First    Male         Southampton
# 2           First  Female         Southampton
# 3           First    Male         Southampton

# %%
dummy_columns.head(4)
# Out:
#    Passenger Class_First  Passenger Class_Second  Passenger Class_Third  \
# 0                   True                   False                  False
# 1                   True                   False                  False
# 2                   True                   False                  False
# 3                   True                   False                  False
#
#    Sex_Female  Sex_Male  Port of Embarkation_Cherbourg  \
# 0        True     False                          False
# 1       False      True                          False
# 2        True     False                          False
# 3       False      True                          False
#
#    Port of Embarkation_Queenstown  Port of Embarkation_Southampton
# 0                           False                             True
# 1                           False                             True
# 2                           False                             True
# 3                           False                             True

# %%
data = pd.concat((df[num_columns], dummy_columns), axis = 1)

# %%
data.head(3)
# Out:
#        Age  No of Siblings or Spouses on Board  \
# 0  29.0000                                   0
# 1   0.9167                                   1
# 2   2.0000                                   1
#
#    No of Parents or Children on Board  Passenger Fare  Passenger Class_First  \
# 0                                   0        211.3375                   True
# 1                                   2        151.5500                   True
# 2                                   2        151.5500                   True
#
#    Passenger Class_Second  Passenger Class_Third  Sex_Female  Sex_Male  \
# 0                   False                  False        True     False
# 1                   False                  False       False      True
# 2                   False                  False        True     False
#
#    Port of Embarkation_Cherbourg  Port of Embarkation_Queenstown  \
# 0                          False                           False
# 1                          False                           False
# 2                          False                           False
#
#    Port of Embarkation_Southampton
# 0                             True
# 1                             True
# 2                             True

# %% [markdown]
# # Build a new model

# %%
x_train, x_test, y_train, y_test = train_test_split(data, df['Survived'], train_size = 0.66, random_state = 5)

# %%
x_train.count()
# Out:
# Age                                   696
# No of Siblings or Spouses on Board    863
# No of Parents or Children on Board    863
# Passenger Fare                        863
# Passenger Class_First                 863
# Passenger Class_Second                863
# Passenger Class_Third                 863
# Sex_Female                            863
# Sex_Male                              863
# Port of Embarkation_Cherbourg         863
# Port of Embarkation_Queenstown        863
# Port of Embarkation_Southampton       863
# dtype: int64

# %%
x_test.count()
# Out:
# Age                                   350
# No of Siblings or Spouses on Board    446
# No of Parents or Children on Board    446
# Passenger Fare                        445
# Passenger Class_First                 446
# Passenger Class_Second                446
# Passenger Class_Third                 446
# Sex_Female                            446
# Sex_Male                              446
# Port of Embarkation_Cherbourg         446
# Port of Embarkation_Queenstown        446
# Port of Embarkation_Southampton       446
# dtype: int64

# %%
mean_age = x_train['Age'].mean()
x_train['Age'] = x_train['Age'].fillna(value = mean_age)

mean_fare = x_train['Passenger Fare'].mean()
x_train['Passenger Fare'] = x_train['Passenger Fare'].fillna(value = mean_fare)


x_test['Age'] = x_test['Age'].fillna(value = mean_age)
x_test['Passenger Fare'] = x_test['Passenger Fare'].fillna(value = mean_fare)

# %%
clf_new = DecisionTreeClassifier(max_depth = 5)

# %%
clf_new.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_pred = clf_new.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7713004484304933
